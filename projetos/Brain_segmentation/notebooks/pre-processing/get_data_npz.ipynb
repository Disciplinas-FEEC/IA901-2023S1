# %% [markdown]
# # Gerar arquivos npz 3D a partir do NIfTI
# * Para o treinamento do modelo, os dados foram convertidos para arquivos no formato npz, por exigir menos custo computacional em relação o NIfTI. Isso acontece por que as informações do cabeçalho não são salvas no arquivo npz neste trabalho e uma vez que os dados estejam corretos e alinhados é mais vantajoso usar os dados em npz durante o treinamento. Nesta implementação, apenas um arquivo npz é salvo para cada sujeito composto pela máscara (mask) e imagem (data) compactado.

# %%
import os
import numpy as np
import glob
import nibabel as nib
import argparse 

def get_npz_3D(data_paths):
    #print(data_paths)
    for data_path in data_paths:
        #print(data_path)
        patient_id = os.path.basename(data_path)
        label_file = 'iso_brainmask_T1w.nii.gz'
        T1_file = 'iso_brain_T1w.nii.gz'
        img_T1 = nib.load(os.path.join(data_path, T1_file))
        img_data_T1 = img_T1.get_fdata()
        img_T1 = img_data_T1
        
        label = nib.load(os.path.join(data_path, label_file))
        label_data = label.get_fdata()
        mask = label_data
        print(f'imagem: sujeito -> {patient_id}, shape -> {img_T1.shape} , máximo -> {img_T1.max()}, mínimo -> {img_T1.min()},' )
        print(f'máscara: sujeito -> {patient_id}, shape -> {mask.shape} , máximo -> {mask.max()}, mínimo -> {mask.min()},' )
        out_name = patient_id + '.npz'
        np.savez_compressed(os.path.join(data_path, out_name), data=img_T1, mask=mask)
        #print(label_data.max())
        #print(label_data.min())
    return img_data_T1, label_data

folder_mri = f"/home/joany/dataset_train/val"
data_paths = glob.glob(os.path.join(folder_mri, "*"))

image, label = get_npz_3D(data_paths)
# Out:
# /home/joany/.local/lib/python3.8/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.17.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# imagem: sujeito -> CC0270, shape -> (256, 196, 256) , máximo -> 4411.0, mínimo -> 0.0,
# máscara: sujeito -> CC0270, shape -> (256, 196, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0291, shape -> (256, 196, 256) , máximo -> 8501.0, mínimo -> 0.0,
# máscara: sujeito -> CC0291, shape -> (256, 196, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00059756, shape -> (256, 256, 192) , máximo -> 1157.0, mínimo -> -1.7563565619244104e-13,
# máscara: sujeito -> A00059756, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0256, shape -> (256, 196, 256) , máximo -> 8329.0, mínimo -> 0.0,
# máscara: sujeito -> CC0256, shape -> (256, 196, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00060372, shape -> (256, 256, 192) , máximo -> 999.0, mínimo -> -1.637711911613507e-13,
# máscara: sujeito -> A00060372, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00061806, shape -> (256, 256, 192) , máximo -> 1708.0, mínimo -> -1.4581313045013145e-13,
# máscara: sujeito -> A00061806, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00060430, shape -> (256, 256, 192) , máximo -> 1229.0, mínimo -> -1.9442937928063064e-13,
# máscara: sujeito -> A00060430, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00061709, shape -> (256, 256, 192) , máximo -> 1255.0, mínimo -> 0.0,
# máscara: sujeito -> A00061709, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0035, shape -> (150, 256, 256) , máximo -> 2827.4521484375, mínimo -> -160.366455078125,
# máscara: sujeito -> CC0035, shape -> (150, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0294, shape -> (256, 196, 256) , máximo -> 6811.0, mínimo -> 0.0,
# máscara: sujeito -> CC0294, shape -> (256, 196, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0051, shape -> (162, 256, 256) , máximo -> 3068.970703125, mínimo -> -178.92967224121094,
# máscara: sujeito -> CC0051, shape -> (162, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0065, shape -> (180, 240, 240) , máximo -> 5301.3564453125, mínimo -> -1.367464626776671e-13,
# máscara: sujeito -> CC0065, shape -> (180, 240, 240) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0129, shape -> (192, 256, 256) , máximo -> 1000.0, mínimo -> 0.0,
# máscara: sujeito -> CC0129, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0126, shape -> (192, 256, 256) , máximo -> 1416.0, mínimo -> 0.0,
# máscara: sujeito -> CC0126, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0009, shape -> (165, 256, 256) , máximo -> 2976.148193359375, mínimo -> -153.19049072265625,
# máscara: sujeito -> CC0009, shape -> (165, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0194, shape -> (298, 256, 256) , máximo -> 1383.0, mínimo -> -28.0,
# máscara: sujeito -> CC0194, shape -> (298, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> S34, shape -> (220, 186, 220) , máximo -> 4036.0, mínimo -> -123.0,
# máscara: sujeito -> S34, shape -> (220, 186, 220) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00060407, shape -> (256, 256, 192) , máximo -> 1143.0, mínimo -> 0.0,
# máscara: sujeito -> A00060407, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00059911, shape -> (256, 256, 192) , máximo -> 1055.0, mínimo -> -1.1451320306495733e-13,
# máscara: sujeito -> A00059911, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0133, shape -> (192, 256, 256) , máximo -> 872.0, mínimo -> 0.0,
# máscara: sujeito -> CC0133, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0293, shape -> (256, 196, 256) , máximo -> 4660.0, mínimo -> 0.0,
# máscara: sujeito -> CC0293, shape -> (256, 196, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0006, shape -> (150, 256, 256) , máximo -> 2751.765380859375, mínimo -> -164.19833374023438,
# máscara: sujeito -> CC0006, shape -> (150, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0117, shape -> (180, 240, 240) , máximo -> 2245971.25, mínimo -> -8.82047629380267e-11,
# máscara: sujeito -> CC0117, shape -> (180, 240, 240) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> S08, shape -> (220, 186, 220) , máximo -> 4019.0, mínimo -> -158.0,
# máscara: sujeito -> S08, shape -> (220, 186, 220) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0025, shape -> (160, 256, 256) , máximo -> 2959.945556640625, mínimo -> -148.5369873046875,
# máscara: sujeito -> CC0025, shape -> (160, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00060169, shape -> (256, 256, 192) , máximo -> 1134.0, mínimo -> -1.4178634937141166e-13,
# máscara: sujeito -> A00060169, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0116, shape -> (180, 240, 240) , máximo -> 2258476.75, mínimo -> -6.107527678045344e-11,
# máscara: sujeito -> CC0116, shape -> (180, 240, 240) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00060279, shape -> (256, 256, 192) , máximo -> 1815.0, mínimo -> -1.7218316345195966e-13,
# máscara: sujeito -> A00060279, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0140, shape -> (192, 256, 256) , máximo -> 978.0, mínimo -> 0.0,
# máscara: sujeito -> CC0140, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0166, shape -> (192, 256, 256) , máximo -> 1072.0, mínimo -> 0.0,
# máscara: sujeito -> CC0166, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0073, shape -> (180, 240, 240) , máximo -> 5866.8681640625, mínimo -> -2.1419282634441844e-13,
# máscara: sujeito -> CC0073, shape -> (180, 240, 240) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0145, shape -> (192, 256, 256) , máximo -> 1078.0, mínimo -> 0.0,
# máscara: sujeito -> CC0145, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0280, shape -> (256, 196, 256) , máximo -> 3514.0, mínimo -> 0.0,
# máscara: sujeito -> CC0280, shape -> (256, 196, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00060093, shape -> (256, 256, 192) , máximo -> 1302.0, mínimo -> -1.692614012274371e-13,
# máscara: sujeito -> A00060093, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0309, shape -> (200, 256, 256) , máximo -> 12093.0, mínimo -> 0.0,
# máscara: sujeito -> CC0309, shape -> (200, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> S33, shape -> (220, 186, 220) , máximo -> 3787.0, mínimo -> -173.0,
# máscara: sujeito -> S33, shape -> (220, 186, 220) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00060480, shape -> (256, 256, 192) , máximo -> 1146.0, mínimo -> -1.878395849237366e-13,
# máscara: sujeito -> A00060480, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0345, shape -> (200, 256, 256) , máximo -> 13071.0, mínimo -> 0.0,
# máscara: sujeito -> CC0345, shape -> (200, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0084, shape -> (180, 240, 240) , máximo -> 4269.7109375, mínimo -> -9.704794612245063e-14,
# máscara: sujeito -> CC0084, shape -> (180, 240, 240) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0131, shape -> (192, 256, 256) , máximo -> 1892.0, mínimo -> 0.0,
# máscara: sujeito -> CC0131, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00062210, shape -> (256, 256, 192) , máximo -> 1643.0, mínimo -> -1.6665640222013334e-13,
# máscara: sujeito -> A00062210, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0302, shape -> (200, 256, 256) , máximo -> 12918.0, mínimo -> 0.0,
# máscara: sujeito -> CC0302, shape -> (200, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0277, shape -> (256, 196, 256) , máximo -> 8656.0, mínimo -> 0.0,
# máscara: sujeito -> CC0277, shape -> (256, 196, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0158, shape -> (192, 256, 256) , máximo -> 1160.0, mínimo -> 0.0,
# máscara: sujeito -> CC0158, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0195, shape -> (298, 256, 256) , máximo -> 1774.0, mínimo -> -62.0,
# máscara: sujeito -> CC0195, shape -> (298, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0135, shape -> (192, 256, 256) , máximo -> 998.0, mínimo -> 0.0,
# máscara: sujeito -> CC0135, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0075, shape -> (180, 240, 240) , máximo -> 4584.533203125, mínimo -> -1.1889342049938023e-13,
# máscara: sujeito -> CC0075, shape -> (180, 240, 240) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00060471, shape -> (256, 256, 192) , máximo -> 1086.0, mínimo -> -1.5157931062669688e-13,
# máscara: sujeito -> A00060471, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00062248, shape -> (256, 256, 192) , máximo -> 1322.0, mínimo -> -1.9160831233287767e-13,
# máscara: sujeito -> A00062248, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> S23, shape -> (220, 186, 220) , máximo -> 4057.0, mínimo -> -184.0,
# máscara: sujeito -> S23, shape -> (220, 186, 220) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0160, shape -> (192, 256, 256) , máximo -> 998.0, mínimo -> 0.0,
# máscara: sujeito -> CC0160, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0265, shape -> (256, 208, 256) , máximo -> 7502.0, mínimo -> 0.0,
# máscara: sujeito -> CC0265, shape -> (256, 208, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> S31, shape -> (220, 186, 220) , máximo -> 3821.0, mínimo -> -192.0,
# máscara: sujeito -> S31, shape -> (220, 186, 220) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00060516, shape -> (256, 256, 192) , máximo -> 1138.0, mínimo -> 0.0,
# máscara: sujeito -> A00060516, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0011, shape -> (150, 256, 256) , máximo -> 3007.070068359375, mínimo -> -176.45159912109375,
# máscara: sujeito -> CC0011, shape -> (150, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0031, shape -> (150, 256, 256) , máximo -> 2895.754638671875, mínimo -> -173.88961791992188,
# máscara: sujeito -> CC0031, shape -> (150, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0057, shape -> (150, 256, 256) , máximo -> 2887.47265625, mínimo -> -160.10850524902344,
# máscara: sujeito -> CC0057, shape -> (150, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0150, shape -> (192, 256, 256) , máximo -> 1242.0, mínimo -> 0.0,
# máscara: sujeito -> CC0150, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0078, shape -> (180, 240, 240) , máximo -> 5620.93505859375, mínimo -> -4.151165359806558e-13,
# máscara: sujeito -> CC0078, shape -> (180, 240, 240) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0147, shape -> (192, 256, 256) , máximo -> 1045.0, mínimo -> 0.0,
# máscara: sujeito -> CC0147, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0232, shape -> (298, 256, 256) , máximo -> 2083.0, mínimo -> -48.0,
# máscara: sujeito -> CC0232, shape -> (298, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00060848, shape -> (256, 256, 192) , máximo -> 1427.0, mínimo -> -1.931099323417701e-13,
# máscara: sujeito -> A00060848, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0159, shape -> (192, 256, 256) , máximo -> 954.0, mínimo -> 0.0,
# máscara: sujeito -> CC0159, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00060925, shape -> (256, 256, 192) , máximo -> 1109.0, mínimo -> -1.5276227006456866e-13,
# máscara: sujeito -> A00060925, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0095, shape -> (180, 240, 240) , máximo -> 4012.1123046875, mínimo -> -5.115104845763996e-13,
# máscara: sujeito -> CC0095, shape -> (180, 240, 240) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0161, shape -> (192, 256, 256) , máximo -> 1687.0, mínimo -> 0.0,
# máscara: sujeito -> CC0161, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0173, shape -> (192, 256, 256) , máximo -> 1125.0, mínimo -> 0.0,
# máscara: sujeito -> CC0173, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0005, shape -> (160, 256, 256) , máximo -> 3120.095458984375, mínimo -> -241.90518188476562,
# máscara: sujeito -> CC0005, shape -> (160, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0042, shape -> (150, 256, 256) , máximo -> 2808.40478515625, mínimo -> -170.3428955078125,
# máscara: sujeito -> CC0042, shape -> (150, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> S09, shape -> (220, 180, 220) , máximo -> 3996.0, mínimo -> -147.0,
# máscara: sujeito -> S09, shape -> (220, 180, 220) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> S17, shape -> (220, 186, 220) , máximo -> 3879.0, mínimo -> -180.0,
# máscara: sujeito -> S17, shape -> (220, 186, 220) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0072, shape -> (180, 240, 240) , máximo -> 5927.03173828125, mínimo -> -3.3460175819302607e-13,
# máscara: sujeito -> CC0072, shape -> (180, 240, 240) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0104, shape -> (180, 240, 240) , máximo -> 5861.28759765625, mínimo -> -3.749588530291281e-13,
# máscara: sujeito -> CC0104, shape -> (180, 240, 240) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0002, shape -> (150, 256, 256) , máximo -> 3268.48193359375, mínimo -> -113.0838851928711,
# máscara: sujeito -> CC0002, shape -> (150, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0076, shape -> (180, 240, 240) , máximo -> 4792.205078125, mínimo -> -1.8077092557231e-13,
# máscara: sujeito -> CC0076, shape -> (180, 240, 240) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0061, shape -> (180, 240, 240) , máximo -> 3606.23291015625, mínimo -> -3.994269379224008e-13,
# máscara: sujeito -> CC0061, shape -> (180, 240, 240) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00061276, shape -> (256, 256, 192) , máximo -> 1571.0, mínimo -> -1.9714529217017968e-13,
# máscara: sujeito -> A00061276, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0245, shape -> (256, 196, 256) , máximo -> 4115.0, mínimo -> 0.0,
# máscara: sujeito -> CC0245, shape -> (256, 196, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00061387, shape -> (256, 256, 192) , máximo -> 1170.0, mínimo -> -1.140584615687626e-13,
# máscara: sujeito -> A00061387, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0292, shape -> (256, 200, 256) , máximo -> 9403.0, mínimo -> 0.0,
# máscara: sujeito -> CC0292, shape -> (256, 200, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00060259, shape -> (256, 256, 192) , máximo -> 1193.0, mínimo -> -1.6032978438808299e-13,
# máscara: sujeito -> A00060259, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00059845, shape -> (256, 256, 192) , máximo -> 1292.0, mínimo -> -1.6146007870542628e-13,
# máscara: sujeito -> A00059845, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0077, shape -> (180, 240, 240) , máximo -> 4787.44580078125, mínimo -> -9.023016437747361e-14,
# máscara: sujeito -> CC0077, shape -> (180, 240, 240) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0354, shape -> (200, 256, 256) , máximo -> 9239.0, mínimo -> 0.0,
# máscara: sujeito -> CC0354, shape -> (200, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00060632, shape -> (256, 256, 192) , máximo -> 1273.0, mínimo -> -1.4686022580326363e-13,
# máscara: sujeito -> A00060632, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0251, shape -> (256, 204, 256) , máximo -> 5353.0, mínimo -> 0.0,
# máscara: sujeito -> CC0251, shape -> (256, 204, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0205, shape -> (298, 256, 256) , máximo -> 1688.0, mínimo -> -50.0,
# máscara: sujeito -> CC0205, shape -> (298, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00061204, shape -> (256, 256, 192) , máximo -> 1311.0, mínimo -> -1.6474163342088816e-13,
# máscara: sujeito -> A00061204, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0174, shape -> (192, 256, 256) , máximo -> 1029.0, mínimo -> 0.0,
# máscara: sujeito -> CC0174, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0324, shape -> (200, 256, 256) , máximo -> 23826.0, mínimo -> 0.0,
# máscara: sujeito -> CC0324, shape -> (200, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00060006, shape -> (256, 256, 192) , máximo -> 2541.0, mínimo -> -2.4090871983926954e-13,
# máscara: sujeito -> A00060006, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0223, shape -> (298, 256, 256) , máximo -> 1869.0, mínimo -> -29.0,
# máscara: sujeito -> CC0223, shape -> (298, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> S21, shape -> (220, 186, 220) , máximo -> 4132.0, mínimo -> -157.0,
# máscara: sujeito -> S21, shape -> (220, 186, 220) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0148, shape -> (192, 256, 256) , máximo -> 1006.0, mínimo -> 0.0,
# máscara: sujeito -> CC0148, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0170, shape -> (192, 256, 256) , máximo -> 1093.0, mínimo -> 0.0,
# máscara: sujeito -> CC0170, shape -> (192, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0015, shape -> (150, 256, 256) , máximo -> 3114.306640625, mínimo -> -182.1902313232422,
# máscara: sujeito -> CC0015, shape -> (150, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0096, shape -> (180, 240, 240) , máximo -> 4152.62060546875, mínimo -> -1.6237113379096585e-13,
# máscara: sujeito -> CC0096, shape -> (180, 240, 240) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0310, shape -> (200, 256, 256) , máximo -> 11595.0, mínimo -> 0.0,
# máscara: sujeito -> CC0310, shape -> (200, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0209, shape -> (298, 256, 256) , máximo -> 1814.0, mínimo -> -45.0,
# máscara: sujeito -> CC0209, shape -> (298, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0047, shape -> (165, 263, 263) , máximo -> 2818.55712890625, mínimo -> -198.6864471435547,
# máscara: sujeito -> CC0047, shape -> (165, 263, 263) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0206, shape -> (298, 256, 256) , máximo -> 2181.0, mínimo -> -61.0,
# máscara: sujeito -> CC0206, shape -> (298, 256, 256) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> A00061711, shape -> (256, 256, 192) , máximo -> 1179.0, mínimo -> -1.4904174899452172e-13,
# máscara: sujeito -> A00061711, shape -> (256, 256, 192) , máximo -> 1.0, mínimo -> 0.0,
# imagem: sujeito -> CC0318, shape -> (200, 256, 256) , máximo -> 19360.0, mínimo -> 0.0,
# máscara: sujeito -> CC0318, shape -> (200, 256, 256) , máximo -> 1.0, mínimo -> 0.0,

# %% [markdown]
# # Visualização dos dados em npz:
# * A cédula abaixo apenas mostra os dados npz para um sujeito de um conjunto de dados. O objetivo disso é conferir se os dados que serão usados no treinamento esta alinhado com a imagem. A linha 1 mostra as imagens, a linha 2 mostra a máscara e a linha 3 a sobreposição entre a máscara e a imagem, nos três cortes.

# %%
# vizualisação 3D
import numpy as np
import matplotlib.pyplot as plt
#arq_npz = np.load("/home/joany/CC0001/CC0001.npz")
arq_npz = np.load("/home/joany/dataset_train/train/CC0001/CC0001.npz")
image = arq_npz['data']
#image1 = np.rot90(image, k=1, axes=(1, -1))
#image2 = np.rot90(image, k=1, axes=(0, -1))
#image3 = np.rot90(image, k=1, axes=(1, 0))
#image = np.transpose(image, (1, 0, 2))
mask = arq_npz['mask']
image.shape

plt.figure("Check", (20, 10))
plt.subplot(3, 3, 1)
plt.title(f"Sagital (imagem); shape:{image.shape}")
plt.axis('off')
plt.imshow(image[128,:,:], cmap = 'gray')
plt.subplot(3, 3, 2)
plt.title(f"Coronal (imagem); shape:{image.shape}")
plt.axis('off')
plt.imshow(image[:,100,:], cmap = 'gray')
plt.subplot(3, 3, 3)
plt.title(f"Axial (imagem); shape:{image.shape}")
plt.axis('off')
plt.imshow(image[:,:,100], cmap = 'gray')
plt.subplot(3, 3, 4)
plt.title(f"Sagital (máscara); shape:{mask.shape}")
plt.axis('off')
plt.imshow(mask[128,:,:], cmap = 'gray')
plt.subplot(3, 3, 5)
plt.title(f"Coronal (máscara); shape:{mask.shape}")
plt.axis('off')
plt.imshow(mask[:,100,:], cmap = 'gray')
plt.subplot(3, 3, 6)
plt.title(f"Axial (máscara); shape:{mask.shape}")
plt.axis('off')
plt.imshow(mask[:,:,100], cmap = 'gray')
plt.subplot(3, 3, 7)
plt.title(f"Sagital (Sobreposição); shape:{mask.shape}")
plt.axis('off')
plt.imshow(image[128, :, :], cmap='gray')
plt.imshow(mask[128, :, :], alpha=0.5, cmap='OrRd')
plt.subplot(3, 3, 8)
plt.title(f"Coronal (Sobreposição); shape:{mask.shape}")
plt.axis('off')
plt.imshow(image[:, 100, :], cmap='gray')
plt.imshow(mask[:, 100, :], alpha=0.5, cmap='OrRd')
plt.subplot(3, 3, 9)
plt.title(f"Axial (Sobreposição); shape:{mask.shape}")
plt.axis('off')
plt.imshow(image[:, :, 100], cmap='gray')
plt.imshow(mask[:, :, 100], alpha=0.5, cmap='OrRd')
print(image.shape)
#(2, 112, 137, 107)
# Out:
# (171, 256, 256)

# %% [markdown]
# ## Mover o npz para outra pastas para realização do treinamento.
# * Depois de gerar os npzs na mesma pasta que estão o NIfTI de cada sujeito, eles são movidos para uma pasta nomeada com o nome do pré-processamento que foi aplicado, por exemplo, dataset_voxels_interpolation. Indica que houve o pré-processamento de interpolação de voxel.

# %%
import os
import glob
import shutil
import os
import numpy as np
file_paths = list(glob.iglob("/home/joany/dataset_train/train/*/*.npz", recursive=True)) 
for data_path in file_paths:
    patient_id = os.path.dirname(data_path)
    patient_id = patient_id.split('/')[-1]
    print(patient_id)
    
    os.makedirs("/home/joany/dataset_train/dataset_normalization/train/" + patient_id, exist_ok=True)
    try:
        shutil.move(data_path, "/home/joany/dataset_train/dataset_normalization/train/" + patient_id)
    except:
        continue
# Out:
# CC0018
# CC0241
# CC0098
# CC0022
# A00038642
# CC0071
# CC0323
# A00057444
# CC0113
# A00043520
# CC0264
# A00053475
# CC0320
# CC0344
# CC0016
# CC0289
# CC0156
# CC0297
# CC0273
# CC0036
# A00057005
# S12
# A00037511
# CC0151
# A00057965
# CC0130
# CC0197
# A00040573
# CC0358
# CC0216
# S40
# A00053851
# CC0329
# CC0210
# A00039391
# A00040524
# CC0255
# CC0233
# CC0236
# CC0118
# CC0314
# CC0100
# S20
# CC0102
# S38
# CC0338
# CC0234
# CC0307
# CC0024
# CC0086
# CC0260
# A00053850
# CC0272
# CC0254
# CC0325
# A00039431
# CC0154
# CC0215
# S28
# CC0021
# CC0063
# CC0303
# S03
# A00051539
# CC0054
# CC0326
# CC0188
# CC0033
# CC0128
# CC0168
# S39
# CC0132
# CC0091
# CC0114
# CC0055
# CC0230
# CC0111
# A00057372
# CC0089
# A00043704
# A00028352
# CC0008
# A00056452
# CC0279
# A00056627
# CC0287
# CC0014
# A00055446
# S15
# CC0322
# A00054441
# CC0164
# A00054857
# CC0343
# CC0074
# S37
# A00053473
# CC0027
# A00045590
# CC0067
# A00055121
# CC0105
# CC0321
# CC0221
# CC0266
# CC0146
# CC0196
# CC0353
# A00056556
# CC0041
# A00038998
# A00035827
# CC0200
# CC0247
# CC0064
# CC0182
# CC0217
# A00055763
# CC0355
# CC0239
# CC0110
# CC0106
# CC0046
# CC0043
# A00058552
# CC0199
# CC0097
# A00051548
# CC0056
# A00058214
# A00043677
# A00059344
# CC0059
# S36
# CC0227
# CC0083
# CC0178
# CC0020
# CC0278
# CC0045
# CC0185
# CC0012
# CC0327
# CC0282
# S16
# CC0242
# CC0187
# CC0208
# CC0275
# A00043721
# CC0228
# CC0263
# A00054019
# A00052125
# CC0186
# A00058952
# A00052181
# S07
# CC0269
# CC0162
# CC0331
# CC0023
# CC0032
# CC0319
# CC0330
# CC0335
# CC0068
# CC0138
# CC0313
# A00032875
# CC0192
# A00043722
# CC0238
# CC0337
# A00033747
# CC0107
# CC0288
# CC0193
# CC0099
# CC0286
# CC0179
# A00055447
# A00052500
# S04
# CC0283
# CC0029
# CC0226
# CC0340
# A00055373
# CC0169
# CC0284
# CC0167
# CC0109
# S14
# CC0177
# CC0296
# S01
# CC0261
# A00058999
# A00053902
# CC0171
# S26
# A00040151
# A00052560
# CC0176
# CC0204
# CC0124
# S02
# CC0144
# CC0136
# CC0175
# S24
# CC0218
# CC0229
# CC0101
# CC0085
# CC0339
# A00055806
# A00056306
# CC0211
# CC0198
# CC0112
# CC0149
# CC0342
# A00035840
# CC0001
# A00051676
# CC0348
# A00028185
# CC0163
# CC0134
# CC0019
# CC0219
# CC0040
# CC0119
# CC0058
# CC0013
# A00056949
# CC0017
# A00056898
# CC0301
# CC0222
# A00054504
# A00058503
# CC0225
# CC0069
# CC0201
# CC0220
# CC0356
# CC0306
# A00057182
# CC0093
# A00040628
# CC0258
# A00037848
# CC0262
# CC0253
# CC0336
# A00055738
# CC0257
# S10
# A00050940
# CC0143
# CC0165
# S25
# A00053455
# CC0103
# CC0347
# CC0122
# CC0271
# CC0224
# CC0087
# CC0172
# A00058218
# CC0082
# CC0030
# CC0115
# CC0214
# CC0142
# A00054914
# CC0044
# CC0039
# CC0231
# CC0249
# CC0212
# A00051927
# CC0281
# A00040623
# A00034854
# S32
# S22
# CC0246
# CC0139
# CC0267
# CC0155
# CC0311
# S06
# CC0152
# CC0052
# CC0037
# CC0244
# CC0357
# S18
# CC0050
# S13
# CC0053
# CC0328
# A00056097
# CC0274
# CC0295
# CC0092
# CC0312
# CC0243
# CC0308
# CC0334
# S30
# A00037112
# CC0153
# CC0137
# CC0070
# CC0062
# CC0237
# S27
# CC0094
# A00040193
# CC0007
# CC0299
# CC0285
# CC0341
# CC0088
# CC0290
# CC0048
# CC0235
# CC0028
# CC0079
# CC0268
# A00040640
# CC0190
# CC0248
# CC0123
# CC0010
# CC0066
# CC0352
# CC0304
# CC0108
# CC0191
# CC0298
# CC0038
# CC0350
# A00052340
# CC0157
# A00057808
# CC0349
# A00057035
# CC0184
# A00058667
# A00057235
# CC0081
# CC0026
# CC0141
# CC0034
# CC0090
# CC0252
# CC0203
# CC0207
# A00057203
# A00057786
# A00035072
# A00059428
# A00043299
# CC0127
# CC0259
# CC0125
# CC0049
# CC0202
# CC0183
# CC0316
# CC0333
# CC0189
# A00043998
# CC0317
# A00059346
# S29
# CC0351
# CC0332
# CC0346
# CC0250
# A00055542
# CC0359
# CC0315
# CC0213
# A00040944

# %% [markdown]
# # obter o 2D a partir do 3D npz
# * Sugestão para gerar o 2D a partir do 3D.

# %%
def read_file(data_paths): 
    for data_path in data_paths:
        patient_id = os.path.basename(data_path)
        FA_file = patient_id + '.npz'
        print(data_path)
        arq_npz = np.load(os.path.join(data_path, FA_file))
        image = arq_npz['data']
        mask = arq_npz['mask']
        shape = image.shape
        nslices = image.shape[0]
        for n in range(nslices):
            save_path = os.path.join(data_path, f"slice{n}_DD.npz")  
            np.savez_compressed(save_path, data=image[n, :, :], mask = mask[n, :, :])
    return image, mask
