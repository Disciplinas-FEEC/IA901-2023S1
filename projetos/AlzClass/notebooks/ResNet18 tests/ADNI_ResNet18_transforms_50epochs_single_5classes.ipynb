# %% [markdown]
# # Imports

# %%
# Checa ambiente - se rodando local não usa o Google Drive
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

# %%
if (IN_COLAB):
    # !pip install pytorch_lightning -qqq
    # !pip install neptune
    from google.colab import drive
    drive.mount('/content/gdrive')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: neptune in /usr/local/lib/python3.10/dist-packages (1.3.1)
# Requirement already satisfied: GitPython>=2.0.8 in /usr/local/lib/python3.10/dist-packages (from neptune) (3.1.31)
# Requirement already satisfied: Pillow>=1.1.6 in /usr/local/lib/python3.10/dist-packages (from neptune) (8.4.0)
# Requirement already satisfied: PyJWT in /usr/local/lib/python3.10/dist-packages (from neptune) (2.7.0)
# Requirement already satisfied: boto3>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (1.26.159)
# Requirement already satisfied: bravado<12.0.0,>=11.0.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (11.0.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (8.1.3)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from neptune) (0.18.3)
# Requirement already satisfied: oauthlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (3.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from neptune) (23.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from neptune) (1.5.3)
# Requirement already satisfied: pipreqs>=0.4 in /usr/local/lib/python3.10/dist-packages (from neptune) (0.4.13)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from neptune) (5.9.5)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (2.27.1)
# Requirement already satisfied: requests-oauthlib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (1.3.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (1.16.0)
# Requirement already satisfied: swagger-spec-validator>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from neptune) (3.0.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from neptune) (1.26.15)
# Requirement already satisfied: websocket-client!=1.0.0,>=0.35.0 in /usr/local/lib/python3.10/dist-packages (from neptune) (1.5.1)
# Requirement already satisfied: botocore<1.30.0,>=1.29.159 in /usr/local/lib/python3.10/dist-packages (from boto3>=1.16.0->neptune) (1.29.159)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3>=1.16.0->neptune) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from boto3>=1.16.0->neptune) (0.6.1)
# Requirement already satisfied: bravado-core>=5.16.1 in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune) (5.17.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune) (1.0.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune) (2.8.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune) (6.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune) (3.19.1)
# Requirement already satisfied: monotonic in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune) (1.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune) (4.5.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython>=2.0.8->neptune) (4.0.10)
# Requirement already satisfied: docopt in /usr/local/lib/python3.10/dist-packages (from pipreqs>=0.4->neptune) (0.6.2)
# Requirement already satisfied: yarg in /usr/local/lib/python3.10/dist-packages (from pipreqs>=0.4->neptune) (0.1.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->neptune) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->neptune) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->neptune) (3.4)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from swagger-spec-validator>=2.7.4->neptune) (4.3.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->neptune) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->neptune) (1.22.4)
# Requirement already satisfied: jsonref in /usr/local/lib/python3.10/dist-packages (from bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune) (1.1.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython>=2.0.8->neptune) (5.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune) (0.19.3)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune) (2.4)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune) (0.1.4)
# Requirement already satisfied: rfc3987 in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune) (1.3.8)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from isoduration->jsonschema->swagger-spec-validator>=2.7.4->neptune) (1.2.3)
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
import random
import numpy as np
import pandas as pd
from tqdm import tqdm
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import random_split
from torch.utils.data import DataLoader, Dataset, Subset
from torch.utils.data import random_split, SubsetRandomSampler
from torchvision import datasets, transforms, models
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor
from torchvision.utils import make_grid
from pytorch_lightning import LightningModule
from pytorch_lightning import Trainer
import pytorch_lightning as pl
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image
import neptune

# %%
# %env NEPTUNE_ALLOW_SELF_SIGNED_CERTIFICATE='TRUE'
run = neptune.init_run(
    project="lais-oliveira/IA901-Projfinal-ADNI",
    api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiJiYmYzNTE1NS0zNzc4LTRmNTctOTIwZC0xNTEyZTRiMmFhMzEifQ==")  # your credentials
# Out:
# env: NEPTUNE_ALLOW_SELF_SIGNED_CERTIFICATE='TRUE'
# https://app.neptune.ai/lais-oliveira/IA901-Projfinal-ADNI/e/IAP1-3

# %%
# Redução das mensagens de log no terminal.
import logging
log = logging.getLogger("pytorch_lightning")
log.propagate = False
log.setLevel(logging.ERROR)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Carregamento dos dados

# %%
if (IN_COLAB):
    root = '/content/gdrive/MyDrive/IA901A_Projeto/data/interim/ADNI4'
else:
    root = '../../../data/interim/ADNI4'

# %%
def setup_transforms(tfGrayscale, tfRdRotate, tfHzFlip, tfResize, tfCtrCrop, tfNormalize):
    tfList = []

    if(tfGrayscale):
        tfList.append(transforms.Grayscale(num_output_channels=3))

    if(tfRdRotate):
        tfList.append(transforms.RandomRotation(10))

    if (tfHzFlip):
        tfList.append(transforms.RandomHorizontalFlip())

    if (tfResize):
        tfList.append(transforms.Resize(224))

    if (tfCtrCrop):
        tfList.append(transforms.CenterCrop(224))

    tfList.append(transforms.ToTensor())

    if (tfNormalize):
        tfList.append(transforms.Normalize([0.485, 0.456, 0.406],
                            [0.229, 0.224, 0.225]))

    transform_lst = transforms.Compose(tfList)

    return transform_lst

# %%
def transforms_text(tfGrayscale, tfRdRotate, tfHzFlip, tfResize, tfCtrCrop, tfNormalize):
    tfText = "Base"

    if(tfGrayscale):
        tfText = tfText + "+Grayscale"

    if(tfRdRotate):
        tfText = tfText + "+Random Rotation"

    if (tfHzFlip):
        tfText = tfText + "+Random Hz Flip"

    if (tfResize):
        tfText = tfText + "+Resize"

    if (tfCtrCrop):
        tfText = tfText + "+Center Crop"

    if (tfNormalize):
        tfText = tfText + "+Normalization"

    return tfText

# %%
from collections import Counter

dataset_train=datasets.ImageFolder(root=root+'/train',transform=None)
print(len(dataset_train))
class_names=dataset_train.classes
print(class_names)
print(len(class_names))

print("Número de amostras por classe: ", dict(Counter(dataset_train.targets)))

dataset_val=datasets.ImageFolder(root=root+'/val',transform=None)
print(len(dataset_val))

print("Número de amostras por classe: ", dict(Counter(dataset_val.targets)))

dataset_test=datasets.ImageFolder(root=root+'/test',transform=None)
print(len(dataset_test))

print("Número de amostras por classe: ", dict(Counter(dataset_test.targets)))
# Out:
# 3700
# ['AD', 'CN', 'EMCI', 'LMCI', 'MCI']
# 5
# Número de amostras por classe:  {0: 500, 1: 1026, 2: 860, 3: 438, 4: 876}
# 834
# Número de amostras por classe:  {0: 109, 1: 257, 2: 173, 3: 92, 4: 203}
# 834
# Número de amostras por classe:  {0: 108, 1: 236, 2: 189, 3: 106, 4: 195}

# %%
class DataModule(pl.LightningDataModule):

    def __init__(self, transform, batch_size):
        super().__init__()
        self.root_dir = root
        self.transform = transform
        self.batch_size = batch_size

    def setup(self, stage=None):
        #dataset = datasets.ImageFolder(root=self.root_dir, transform=self.transform)
        #n_data = len(dataset)
        #n_train = int(0.7 * n_data)
        #n_val = int(0.15 * n_data)
        #n_test = n_data - (n_train + n_val)

        #train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(dataset, [n_train, n_val, n_test], generator=torch.Generator().manual_seed(42))

        train_folder = self.root_dir + '/train'
        val_folder = self.root_dir + '/val'
        test_folder = self.root_dir + '/test'
        train_dataset = datasets.ImageFolder(train_folder, transform=self.transform)
        val_dataset = datasets.ImageFolder(val_folder, transform=self.transform)
        test_dataset = datasets.ImageFolder(test_folder, transform=self.transform)

        self.train_dataset = DataLoader(train_dataset, batch_size=self.batch_size, num_workers=3, shuffle=True)
        self.val_dataset = DataLoader(val_dataset, batch_size=self.batch_size, num_workers=3, shuffle=True)
        self.test_dataset = DataLoader(test_dataset, batch_size=self.batch_size, num_workers=3, shuffle=True)

    def train_dataloader(self):
        return self.train_dataset

    def val_dataloader(self):
        return self.val_dataset

    def test_dataloader(self):
        return self.test_dataset

# %%
# Datamodule baseados nas transformações

batch_size = 1
# Definição das transformações a serem utilizadas
tfGrayscale = False
tfRdRotate = False
tfHzFlip = False
tfResize = False
tfCtrCrop = False
tfNormalize = False

transforms_set = setup_transforms(tfGrayscale, tfRdRotate, tfHzFlip, tfResize, tfCtrCrop, tfNormalize)
datamodule = DataModule(transforms_set, batch_size)
datamodule.setup()
# Out:
# /content/gdrive/MyDrive/IA901A_Projeto/data/interim/ADNI4/train

# %% [markdown]
# # Vizualizando imagens

# %%
for images, labels in datamodule.train_dataloader():
    break
im=make_grid(images,nrow=16)

plt.figure(figsize=(12,12))
plt.imshow(np.transpose(im.numpy(),(1,2,0)))

# %% [markdown]
# # Definindo e treinando o modelo base: AlexNet

# %%
print(len(class_names))
# Out:
# 3

# %% [markdown]
# ## Funções para definição do modelo, treinamento, testes e métricas

# %%
import torchmetrics
from torchmetrics import MetricCollection
from torchmetrics.classification import MulticlassAccuracy, MulticlassPrecision, MulticlassRecall

class MyModel(LightningModule):

    def __init__(self, lr):
        num_classes = len(class_names)
        super().__init__()
        self.lr = lr
        #self.model = models.resnet18(weights = models.ResNet18_Weights.IMAGENET1K_V1)
        self.model = models.resnet18(pretrained=True)
        num_ftrs = self.model.fc.in_features
        self.model.fc = nn.Linear(num_ftrs,len(class_names))

        # TorchMetrics
        metrics = MetricCollection([
            MulticlassAccuracy(num_classes),
            MulticlassPrecision(num_classes),
            MulticlassRecall(num_classes)
        ])
        self.train_metrics = metrics.clone(prefix='train_')
        self.val_metrics = metrics.clone(prefix='val_')
        self.test_metrics = metrics.clone(prefix='test_')

    def forward(self, x):
        x = self.model(x)
        return x

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), self.lr)
        return optimizer

    def training_step(self, train_batch, batch_idx):
        X, y = train_batch
        y_hat = self(X)

        loss = F.cross_entropy(y_hat, y)
        pred = torch.flatten(y_hat.argmax(dim=1, keepdim=True))

        acc = pred.eq(y.view_as(pred)).sum().item() / y.shape[0]
        output = self.train_metrics(pred, y)

        run["train/loss"].append(loss)
        run["train/acc"].append(acc)
        run["train/multiclassacc"].append(output["train_MulticlassAccuracy"])

        self.log("train_loss", loss)
        self.log("train_acc", acc)
        self.log_dict(output)

        return loss

    def validation_step(self, val_batch, batch_idx):
        X, y = val_batch
        y_hat = self(X)

        loss = F.cross_entropy(y_hat, y)
        pred = torch.flatten(y_hat.argmax(dim=1, keepdim=True))

        acc = pred.eq(y.view_as(pred)).sum().item() / y.shape[0]
        output = self.val_metrics(pred, y)

        run["val/loss"].append(loss)
        run["val/acc"].append(acc)
        run["val/multiclassacc"].append(output["val_MulticlassAccuracy"])

        self.log("val_loss", loss)
        self.log("val_acc", acc)
        self.log_dict(output)

    def test_step(self, test_batch, batch_idx):
        X, y = test_batch
        y_hat = self(X)

        loss = F.cross_entropy(y_hat, y)
        pred = torch.flatten(y_hat.argmax(dim=1, keepdim=True))

        acc = pred.eq(y.view_as(pred)).sum().item() / y.shape[0]

        if (batch_idx == 0):
            self.all_labels = y.clone()
            self.all_preds = pred.clone()
        else:
            self.all_labels = torch.cat((self.all_labels, y))
            self.all_preds = torch.cat((self.all_preds, pred))

        output = self.test_metrics(pred, y)

        self.log("test_loss", loss)
        self.log("test_acc", acc)
        self.log_dict(output)

# %%
def train_model(model, epochs, datamodule):

    trainer = pl.Trainer(max_epochs=epochs)
    trainer.fit(model, datamodule)

    val_loader = datamodule.val_dataloader()
    trainer.validate(dataloaders=val_loader)

    return trainer

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def plot_matrix(title, model):

    ax = plt.subplot()
    cm = confusion_matrix(model.all_labels.cpu(), model.all_preds.cpu())

    sns.set_style("darkgrid")
    sns.set(rc={"figure.figsize":(20, 4)})
    colormap = sns.color_palette("Blues",12)
    sns.heatmap(cm, annot=True, fmt='g', ax=ax, cmap=colormap)

    # labels, title and ticks
    ax.set_xlabel('Predições:')
    ax.set_ylabel('Labels:')
    ax.set_title(title);
    ax.xaxis.set_ticklabels(class_names)
    ax.yaxis.set_ticklabels(class_names, rotation=0)

# %%
def test_model(model, datamodule, trainer, tfText):
    print("Modelo: " + tfText)
    datamodule.setup(stage='test')
    test_loader = datamodule.test_dataloader()
    trainer.test(dataloaders=test_loader)

    plot_matrix("Modelo: "+ tfText, model)

# %% [markdown]
# ## Treinamento e Teste dos Modelos

# %%
batch_size = 1
epochs = 50

# %% [markdown]
# ## Teste de Taxa de Aprendizado

# %%
# Learning Rate
lr = 0.0001

# Definição das transformações a serem utilizadas
tfGrayscale = False
tfRdRotate = False
tfHzFlip = False
tfResize = False
tfCtrCrop = False
tfNormalize = False


transforms_set = setup_transforms(tfGrayscale, tfRdRotate, tfHzFlip, tfResize, tfCtrCrop, tfNormalize)
tf_text = transforms_text(tfGrayscale, tfRdRotate, tfHzFlip, tfResize, tfCtrCrop, tfNormalize) + "LR: " + str(lr)
datamodule = DataModule(transforms_set, batch_size)
datamodule.setup()

model = MyModel(lr)

# Treinamento e Validação
tr = train_model(model, epochs, datamodule)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/call.py in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      41             return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 42         return trainer_fn(*args, **kwargs)
#      43
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/trainer.py in _fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     569         )
# --> 570         self._run(model, ckpt_path=ckpt_path)
#     571
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/trainer.py in _run(self, model, ckpt_path)
#     950         # strategy will configure model and move it to the device
# --> 951         self.strategy.setup(self)
#     952
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/strategies/single_device.py in setup(self, trainer)
#      73     def setup(self, trainer: pl.Trainer) -> None:
# ---> 74         self.model_to_device()
#      75         super().setup(trainer)
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/strategies/single_device.py in model_to_device(self)
#      70         assert self.model is not None, "self.model must be set before self.model.to()"
# ---> 71         self.model.to(self.root_device)
#      72
#
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/utilities/device_dtype_mixin.py in to(self, *args, **kwargs)
#      53         self.__update_properties(device=device, dtype=dtype)
# ---> 54         return super().to(*args, **kwargs)
#      55
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#    1144
# -> 1145         return self._apply(convert)
#    1146
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     796         for module in self.children():
# --> 797             module._apply(fn)
#     798
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     796         for module in self.children():
# --> 797             module._apply(fn)
#     798
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     819             with torch.no_grad():
# --> 820                 param_applied = fn(param)
#     821             should_use_set_data = compute_should_use_set_data(param, param_applied)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in convert(t)
#    1142                             non_blocking, memory_format=convert_to_format)
# -> 1143             return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#    1144
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-46-ee2906132284> in <cell line: 23>()
#      21
#      22 # Treinamento e Validação
# ---> 23 tr = train_model(model, epochs, datamodule)
#
# <ipython-input-41-d8e6e30e7de5> in train_model(model, epochs, datamodule)
#       2
#       3     trainer = pl.Trainer(max_epochs=epochs)
# ----> 4     trainer.fit(model, datamodule)
#       5
#       6     val_loader = datamodule.val_dataloader()
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/trainer.py in fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     529         model = _maybe_unwrap_optimized(model)
#     530         self.strategy._lightning_module = model
# --> 531         call._call_and_handle_interrupt(
#     532             self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     533         )
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/call.py in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      64         for logger in trainer.loggers:
#      65             logger.finalize("failed")
# ---> 66         trainer._teardown()
#      67         # teardown might access the stage so we reset it after
#      68         trainer.state.stage = None
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/trainer.py in _teardown(self)
#     996         """This is the Trainer's internal teardown, unrelated to the `teardown` hooks in LightningModule and
#     997         Callback; those are handled by :meth:`_call_teardown_hook`."""
# --> 998         self.strategy.teardown()
#     999         loop = self._active_loop
#    1000         # loop should never be `None` here but it can because we don't know the trainer stage with `ddp_spawn`
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/strategies/strategy.py in teardown(self)
#     477         self.precision_plugin.teardown()
#     478         assert self.accelerator is not None
# --> 479         self.accelerator.teardown()
#     480         self.checkpoint_io.teardown()
#     481
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/accelerators/cuda.py in teardown(self)
#      74
#      75     def teardown(self) -> None:
# ---> 76         _clear_cuda_memory()
#      77
#      78     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/accelerators/cuda.py in _clear_cuda_memory()
#     363         # https://github.com/pytorch/pytorch/issues/95668
#     364         torch._C._cuda_clearCublasWorkspaces()
# --> 365     torch.cuda.empty_cache()
#
# /usr/local/lib/python3.10/dist-packages/torch/cuda/memory.py in empty_cache()
#     131     """
#     132     if is_initialized():
# --> 133         torch._C._cuda_emptyCache()
#     134
#     135
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
# Testando a base dos testes
test_model(model, datamodule, tr, tf_text)
# Out:
# Modelo: BaseLR: 0.0001
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │  test_MulticlassAccuracy  │    0.3971957564353943     │
# │ test_MulticlassPrecision  │    0.4368782937526703     │
# │   test_MulticlassRecall   │    0.3971957564353943     │
# │         test_acc          │    0.6904761791229248     │
# │         test_loss         │    0.7283541560173035     │
# └───────────────────────────┴───────────────────────────┘

# %%
run.stop()
# Out:
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/fabiogr/Projeto-IA901/e/IA901-19/metadata
